# %% [markdown]
# # Summary Report Template
#
# Start with a brief introduction of your lab here.  Broadly speaking what were the main aims of the module?

# %% [markdown]
# ## Day (or week) 1
#
# Describe the module activities here.  What was the goal for this day/week?  Discuss measurements, results, and findings with data and plots where relevant.  Address all action items/question prompts as provided in the lab instructions.
#
# Some modules are organized by week, and some by day, so you can organize these sections accordingly.

# %% [markdown]
# ## Day (or week) 2
#
# ... continue accordingly ...

# %% [markdown]
# ## Summary and Conclusions
#
# Briefly summarize the lab.  Provide key conclusions, especially in the context of what was learned and why it is important in the context of quantum engineering and technology development.
